# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b  ... workex  etest_p specialisation  mba_p      status    salary
# 0      1      M  67.00   Others  91.00   Others  ...     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1      2      M  79.33  Central  78.33   Others  ...    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2      3      M  65.00  Central  68.00  Central  ...     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3      4      M  56.00  Central  52.00  Central  ...     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4      5      M  85.80  Central  73.60  Central  ...     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
# [5 rows x 15 columns]

# %%
df.shape
# Out:
# (215, 15)

# %%
df[df['status'] == 'Placed'].isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # For salary prediction

# %%
new_df = df[df['status'] == 'Placed']
new_df = new_df[["ssc_p","hsc_p","degree_p","etest_p","mba_p","salary"]]
new_df.head()
# Out:
#    ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1  79.33  78.33     77.48     86.5  66.28  200000.0
# 2  65.00  68.00     64.00     75.0  57.80  250000.0
# 4  85.80  73.60     73.30     96.8  55.50  425000.0
# 7  82.00  64.00     66.00     67.0  62.14  252000.0

# %%
# Assumptions of linear regression
# 1. linear relationship b/w target and geatures
# 2. No Multicorrelanity
# 3. normal residual
# 4. Homoscadisity
# 5. No autocorrelationily residual
#

# %% [markdown]
# # 1. linear relationship b/w target and geatures

# %%
plt.plot(new_df['ssc_p'],new_df['salary'],'o')
plt.xlable('ssc_p')
plt.show()


plt.plot(new_df['hsc_p'],new_df['salary'],'o')
plt.xlable('hsc_p')
plt.show()

plt.plot(new_df['degree_p'],new_df['salary'],'o')
plt.xlable('degree_p')
plt.show()


plt.plot(new_df['etest_p'],new_df['salary'],'o')
plt.xlable('etest_p')
plt.show()


plt.plot(new_df['mba_p'],new_df['salary'],'o')
plt.xlable('mba_p')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 plt.plot(new_df['ssc_p'],new_df['salary'],'o')
# ----> 2 plt.xlable('ssc_p')
#       3 plt.show()
#       6 plt.plot(new_df['hsc_p'],new_df['salary'],'o')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'
