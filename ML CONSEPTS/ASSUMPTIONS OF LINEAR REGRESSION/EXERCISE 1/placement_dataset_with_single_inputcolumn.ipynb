# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
df.shape
# Out:
# (200, 2)

# %% [markdown]
# # Assumptions of Linear Regression

# %%
# 1. relation b/w input column and output column is linear
# 2. No multicorrelinity
# 3. normal residual
# 4. Homoscedicity
# 5. No autocorrelationiy residual
#

# %% [markdown]
# # 1. Relation b/w input column and output column

# %%
plt.plot(df['cgpa'],df['package'],'o')
plt.xlabel('cgpa')
plt.ylabel('package')
plt.show()

# %% [markdown]
# # 2. Multicorrelinity check

# %%
#onle single column is available

# %% [markdown]
# # 3. Normal Residual

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.iloc[:,:1],df.iloc[:,-1],test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
residual = y_pred - y_test

# %%
sns.displot(residual,kind='kde')

# %% [markdown]
# # 4. Homoscadisity

# %%
plt.scatter(y_pred,residual)

# %% [markdown]
# # 5. Autocorrelation of residual

# %%
plt.plot(residual)
