# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.displot(df['cgpa'])


sns.displot(df['package'])
plt.show()

# %%
print("upper limit",df['package'].mean() + 3*df['package'].std())
print("lower limit",df['package'].mean() - 3*df['package'].std())
# Out:
# upper limit 5.0709827233750655
# lower limit 0.9211172766249356

# %%
df[(df['package'] > 5.07) | (df['package'] < 0.921)]
# Out:
# Empty DataFrame
# Columns: [cgpa, package]
# Index: []

# %% [markdown]
# ## No outliers in iq column

# %%
print("upper limit",df['cgpa'].mean() + 3*df['cgpa'].std())
print("lower limit",df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# upper limit 10.198726039668658
# lower limit 3.7822739603313433

# %%
df[(df['cgpa'] > 10.19) | (df['cgpa'] < 3.78)]
# Out:
# Empty DataFrame
# Columns: [cgpa, package]
# Index: []

# %% [markdown]
# ### not outliers in cgpa column
