# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.displot(df['cgpa'])


sns.displot(df['iq'])
plt.show()

# %%
print("upper limit",df['iq'].mean() + 3*df['iq'].std())
print("lower limit",df['iq'].mean() - 3*df['iq'].std())
# Out:
# upper limit 243.4125953532298
# lower limit 3.747404646770221

# %%
df[(df['iq'] > 243.41) | (df['iq'] < 3.747)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, cgpa, iq, placement]
# Index: []

# %% [markdown]
# ## No outliers in iq column

# %%
print("upper limit",df['cgpa'].mean() + 3*df['cgpa'].std())
print("lower limit",df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# upper limit 9.421901021332708
# lower limit 2.560098978667293

# %%
df[(df['cgpa'] > 9.421) | (df['cgpa'] < 2.56)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, cgpa, iq, placement]
# Index: []

# %% [markdown]
# ### not outliers in cgpa column
